# %%
import os
import requests
from bs4 import BeautifulSoup, Tag
import time
import shutil
from urllib.parse import urlparse, parse_qs, unquote

import pandas as pd
import json

# %%
from tqdm import tqdm
tqdm.pandas()

# %%
BASE_URL = 'https://multi-sport.sk/aktivity'

# %%
def get_venue_urls():

    print(f'Processing url: {BASE_URL}')
    r = requests.get(BASE_URL)

    soup = BeautifulSoup(r.content, 'html.parser')

    pagination = soup.find('nav', {'class': 'pagination'})
    n_pages = int(pagination.text.split()[-1])

    venues = []

    for card in soup.findAll('div', {'class': 'facilityCard'}):
        a = card.find('a')
        venues.append({
            'name': a.text,
            'url': a['href']
        })

    for i in range(2, n_pages + 1):

        url = f'{BASE_URL}/page/{i}'
        print(f'Processing url: {url}')
        r = requests.get(url)
        soup = BeautifulSoup(r.content, 'html.parser')

        for card in soup.findAll('div', {'class': 'facilityCard'}):
            a = card.find('a')
            venues.append({
                'name': a.text,
                'url': a['href']
            })

    return venues

# %%
venue_urls = get_venue_urls()
# Out:
# Processing url: https://multi-sport.sk/aktivity
# Processing url: https://multi-sport.sk/aktivity/page/2
# Processing url: https://multi-sport.sk/aktivity/page/3
# Processing url: https://multi-sport.sk/aktivity/page/4
# Processing url: https://multi-sport.sk/aktivity/page/5
# Processing url: https://multi-sport.sk/aktivity/page/6
# Processing url: https://multi-sport.sk/aktivity/page/7
# Processing url: https://multi-sport.sk/aktivity/page/8
# Processing url: https://multi-sport.sk/aktivity/page/9
# Processing url: https://multi-sport.sk/aktivity/page/10
# Processing url: https://multi-sport.sk/aktivity/page/11
# Processing url: https://multi-sport.sk/aktivity/page/12
# Processing url: https://multi-sport.sk/aktivity/page/13
# Processing url: https://multi-sport.sk/aktivity/page/14
# Processing url: https://multi-sport.sk/aktivity/page/15
# Processing url: https://multi-sport.sk/aktivity/page/16
# Processing url: https://multi-sport.sk/aktivity/page/17
# Processing url: https://multi-sport.sk/aktivity/page/18
# Processing url: https://multi-sport.sk/aktivity/page/19
# Processing url: https://multi-sport.sk/aktivity/page/20
# Processing url: https://multi-sport.sk/aktivity/page/21
# Processing url: https://multi-sport.sk/aktivity/page/22
# Processing url: https://multi-sport.sk/aktivity/page/23
# Processing url: https://multi-sport.sk/aktivity/page/24
# Processing url: https://multi-sport.sk/aktivity/page/25
# Processing url: https://multi-sport.sk/aktivity/page/26
# Processing url: https://multi-sport.sk/aktivity/page/27
# Processing url: https://multi-sport.sk/aktivity/page/28
# Processing url: https://multi-sport.sk/aktivity/page/29
# Processing url: https://multi-sport.sk/aktivity/page/30
# Processing url: https://multi-sport.sk/aktivity/page/31
# Processing url: https://multi-sport.sk/aktivity/page/32
# Processing url: https://multi-sport.sk/aktivity/page/33
# Processing url: https://multi-sport.sk/aktivity/page/34
# Processing url: https://multi-sport.sk/aktivity/page/35
# Processing url: https://multi-sport.sk/aktivity/page/36
# Processing url: https://multi-sport.sk/aktivity/page/37
# Processing url: https://multi-sport.sk/aktivity/page/38

# %%
len(venue_urls)
# Out:
# 891

# %%
df = pd.DataFrame({
    'name': [v['name'] for v in venue_urls],
    'url': [v['url'] for v in venue_urls],
})

# %%
df['content'] = df.url.progress_apply(lambda url: requests.get(url).text)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████| 881/881 [04:06<00:00,  3.57it/s]

# %%
def extract_name(content):

    soup = BeautifulSoup(content)
    name = soup.find('h1').text
    return name

def extract_address(content):

    soup = BeautifulSoup(content)
    address = soup.find('address').get_text(strip=True, separator='\n')
    return address

def extract_tags(content):

    soup = BeautifulSoup(content)
    tags = [s.text for s in soup.find_all('span', {'class': 'badge'})]
    return tags

def extract_contact(content):

    soup = BeautifulSoup(content)
    
    phone = None
    email = None
    fb = None
    web = None
    
    for h2 in soup.find_all('h2'):
        if h2.text == 'Kontakt':
            div = h2.find_next_sibling('div')
            for l in div.find_all('a'):
                href = l['href']
                if href.startswith('tel:'):
                    phone = href[4:]
                elif href.startswith('mailto:'):
                    email = unquote(href)[7:]
                elif 'facebook' in href:
                    fb = href
                else:
                    web = href
    return phone, email, fb, web

def extract_description(content):

    soup = BeautifulSoup(content)
    div = soup.find('div', {'class': 'my-4'})
    if not div:
        return None

    text_parts = []
    for child in div.children:
        if isinstance(child, Tag):
            if 'mt-5' in child.attrs.get('class', []):
                break
            text_parts.append(child.text)

    if len(text_parts) == 0:
        return None

    return '\n'.join(text_parts).strip()

def extract_pictures(content):

    logo_url = None
    pictures = None

    soup = BeautifulSoup(content)
    figure = soup.find('figure', {'class': 'text-center'})
    if figure:
        logo_url = figure.find('img').attrs['data-src']

    splide = soup.find('div', {'class': 'splide__list'})
    if splide:
        pictures = [img.attrs['data-src'] for img in splide.find_all('img')]

    return logo_url, pictures

def extract_coords(content):

    soup = BeautifulSoup(content)
    iframe = soup.find('iframe', {'class': 'd-block'})
    parsed_url = urlparse(iframe.attrs['src'])
    coords = parse_qs(parsed_url.query)['q'][0].split(',')
    return coords

# %%
df = pd.read_parquet('data/multisport.parquet')

# %%
df.columns
# Out:
# Index(['name', 'url', 'content', 'address', 'tags', 'phone', 'email',
#        'facebook', 'web', 'description', 'logo', 'pictures'],
#       dtype='object')

# %%
df['name'] = df.content.progress_apply(extract_name)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████| 881/881 [00:10<00:00, 81.51it/s]

# %%
df['address'] = df.content.progress_apply(extract_address)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████| 881/881 [00:10<00:00, 83.54it/s]

# %%
df['tags'] = df.content.progress_apply(extract_tags)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████| 881/881 [00:10<00:00, 82.48it/s]

# %%
df['phone'], df['email'], df['facebook'], df['web'] = zip(*df.content.progress_apply(extract_contact))
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████| 881/881 [00:10<00:00, 81.80it/s]

# %%
df['description'] = df.content.progress_apply(extract_description)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████| 881/881 [00:10<00:00, 82.26it/s]

# %%
df['logo'], df['pictures'] = zip(*df.content.progress_apply(extract_pictures))
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████| 881/881 [00:11<00:00, 79.71it/s]

# %%
df['coordinates'] = df.content.progress_apply(extract_coords)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████| 881/881 [00:10<00:00, 81.92it/s]

# %%
df.to_parquet('data/multisport.parquet', index=False)

# %%
sum(df.pictures.notnull())
# Out:
# 651

# %%
lens = df.pictures.apply(lambda x: 0 if not isinstance(x, list) else len(x))

# %%
lens.value_counts()
# Out:
# pictures
# 3    481
# 0    230
# 2    103
# 1     67
# Name: count, dtype: int64

# %%
sum(df.description.isnull())
# Out:
# 368

# %%
print(sum(df.phone.isnull()))
print(sum(df.email.isnull()))
print(sum(df.facebook.isnull()))
print(sum(df.web.isnull()))
# Out:
# 71
# 816
# 130
# 176

# %%
sum((df.phone.isnull()) & (df.email.isnull()) & (df.facebook.isnull()) & (df.web.isnull()))
# Out:
# 10

# %%
for i, row in df[df.description.notnull()].iterrows():
    print(row['url'])
    print(row['description'])
    print('----------------')
# Out:
# https://multi-sport.sk/aktivity/partner/do-tela-povazska-bystrica/
# Ľudský organizmus je prepracovaný systém a najlepšie funguje, keď je v harmónii, „fyzično a psychično“. Dosiahnúť maximálny potenciál v živote je snom každého človeka, avšak ako na to? BeYourBest vám odpovie.
# ----------------
# https://multi-sport.sk/aktivity/partner/1-tenisovy-klub/
# Využite svoju kartu MultiSport a prídťe si k nám zahrať  tenis.
#
#
#     Informácie o voľných termínoch vám poskytne správca areálu  na telefónnom
#     čísle 0948 – 022 273.
#
#
#     Prajeme skvelý športový zážitok a tešíme sa na vás!
# ----------------
# https://multi-sport.sk/aktivity/partner/24hr-fitness/
# Novootvorené fitness centrum v Bidovciach.
#
#
#
#
#     NO PAIN NO GAIN
#
#
#     Bolesť, ktorú cítiš dnes bude sila, ktorú pocítiš zajtra.
# ----------------
# https://multi-sport.sk/aktivity/partner/365-fit-co-eurovea/
# Na začiatku bola vášeň a obdiv pre jednu z najkrajších a najrýchlejšie rastúcich lokalít Bratislavy a práve preto sme sa rozhodli tu vybudovať výnimočné miesto pre šport a oddych pre mestských ľudí, bez ohľadu na vek a úroveň fyzických schopností, ktorí milujú aktívny život, pohyb a relax. Ponúkané služby Fitness – Jedinečný výhľad na Dunaj, Námestie Eurovea a SND si užijete pri cvičení pri cvičení na profesionálnych strojoch od značky Life Fitness. Súčasťou je kardio zóna, silová zóna a funkčná zóna so starostlivo vybraným vybavením, takže si každý dokáže nastaviť tréning, aký potrebuje. Okrem toho je v letných mesiacoch k dispozícii 800 m2 krytej terasy s krásnym výhľadom pre tréning na čerstvom vzduchu.
#  Skupinové cvičenia – Špeciálna sála navrhnutá pre rôzne druhy skupinových cvičení poskytuje všetko pre kvalitný tréning. Viac info na fitco.sk/skupinove-cvicenia/. Bootcamp&Co – Vyskúšajte našu horúcu workoutovú novinku, pri ktorej môžete spáliť až tisíc kalóriií. Kombinácia dynamického a vytrvalostného tréningu, namixovaných hudobných setov a špeciálneho osvetlenia zaistia, že sa nikdy nebudete nudiť. Viac info na bootcampco.sk.
#   Podmienky využitia služieb Fit&Co, platné od 1.9.2022 VŠEOBECNÉ PRAVIDLÁ:
#  • Pri prvej návšteve vo Fit&Co je potrebná registrácia- odovzdáte Vaše osobné údaje, podpíšete všeobecné podmienky členstva a zaplatíte registračný poplatok vo výške 10 eur, na základe ktorého dostanete kartičku Fit&Co. Táto kartička slúži na vstup a pohyb v priestoroch Fit&Co a ostane Vám k dispozícii aj pre budúce návštevy Fit&Co.
#  • V jeden deň môže držiteľ multisport karty využiť vždy iba 1 z uvedených služieb, maximálne 1 krát.
#
#  Od 1.9.2022 zavádzame obmedzenie kapacity a rezervačný systém do fitness zóny. Rezervácie budú potrebné od pondelka do štvrtka v časoch od 16:00 do 20:00. Časový limit je 100 minút od vstupu po odchod z fitness centra. V prípade prekročenia časového limitu, bude účtovaný doplatok 10,-eur. V ostatných dňoch a časoch rezervácie nie sú potrebné. V prípade že chcete rezerváciu zrušiť bezplatne, je potrebné tak urobiť 3 hodiny pred začiatkom rezervácie. Rezerváciu je potrebné urobiť na: https://membership.fitco.sk/
#  Taktiež sa zavádza časový limit na skupinové cvičenie a to tiež 100 minút. V prípade prekročenia časového limitu, je opäť účtovaný doplatok 10,-eur. V prípade že chcete rezerváciu zrušiť bezplatne, je potrebné tak urobiť 5 hodín pred začiatkom skupinového cvičenia.
# ----------------
# https://multi-sport.sk/aktivity/partner/365-fit-co-oc-eperia-presov/
# Pri prvom vstupe na kartu MultiSport je nutné zaplatiť vstupnú poplatok 10€. Následne vstupy sú už bez poplatkov.
# ----------------
# https://multi-sport.sk/aktivity/partner/365-fit-co-oc-galeria-lamac/
# Sme moderné fitness centrum v obchodnom centre Galéria  Lamač. Okrem fitness
#     zóny ktorá je ako prvá na Slovensku vybavená strojmi  americkej značky
#     PRECOR, u nás nájdete aj fínsku saunu s menšou relaxačnu  zónou.
# ----------------
# https://multi-sport.sk/aktivity/partner/365-golf-range/
# 365 Golf Range v Trenčíne je najmodernejšie golfové  odpalisko na Slovensku
#     a v Čechách.
#
#
#     Na tomto mieste sa stretáva vášeň pre golf s modernými technológiami,
#     zábavou a pohodlím. Ponúka širokú škálu služieb pre všetkých nadšencov
#     golfovej  hry, bez ohľadu na ich skúsenosti.
#
#
#     Pre negolfistov a úplných začiatočníkov, je to ideálne  miesto na zoznámenie
#     sa s golfom v pohodovej atmosfére. K dispozícii máme 10  vyhrievaných kójí s
#     golfovými palicami, nádherným barom a terasou.
#
#
#     Pokročilí hráči si tu môžu zdokonaliť svoje zručnosti a  techniku s využitím
#     najnovších technologických pomôcok, ako je Toptracer či  automatický podávač
#     loptičiek Power Tee alebo Chipping a Putting zóna.
#
#
#     Okrem toho, je 365 Golf Range skvelým miestom pre zábavné  eventy,
#     narodeninové oslavy, teambuildingy a iné spoločenské udalosti.
# ----------------
# https://multi-sport.sk/aktivity/partner/365-gym-topolcany/
# Pod značkou 365 Gym´s sme pre vás otvorili nové fitness centrum v     Topoľčanoch. Pri realizácií sme dbali na každý detail – vstup, ktorý sa     vyznačuje efektivitou (prechod cez turniket pomocou členskej karty), ktorý     eliminuje čakanie na recepcii. Skrinky na báze bankových trezorov na PIN     kód, čím zaručujeme bezpečnosť osobných vecí klienta. Kvalita osvetlenia,     ozvučenia, vzduchotechniky.
#  Najmodernejšie vybavenie kardio strojov     (kardio s obrazovkou, na ktorej sa klientovi premieta virtuálna prechádza     mestom/prírodou, možnosť sledovania TV, Netflix…).              Najkvalitnejšie stroje od značiek Hammer Strength, Verti, Life Fitness          , ktoré svojím množstvom zabezpečia kvalitný tréning až pre 100-150 ľudí     naraz
# ----------------
# https://multi-sport.sk/aktivity/partner/365-gym-trnava/
# Najväčšie , najmodernejšie a najlepšie Fitness Centrum v Trnave a širokom     okolí
# ----------------
# https://multi-sport.sk/aktivity/partner/3g-fit-club/
# FILOZOFIA
#
# 3G fit club ponúka svojim členom    profesionálne služby, moderné vybavenie a špičkový servis
#     v príjemnom prostredí. Zažite u nás tú správnu atmosféru profesionálneho
#     klubu. 3G fit club je tiež miestom príjemného odpočinku, kde sa vždy budete
#     cítit výnimočne. Miestom, ktoré se stane súčasťou Vášho životného štýlu.
#
#
# PREČO CVIČIŤ U NÁS ?
#
#     Keď sa rozhodnete, že sa pohyb stane prirodzenou súčasťou Vášho života, tak
#     už Vám zostáva len jeden krok: cvičit správne.
#
#     V 3G fit clube nájdete
#
#         komplexnú ponuku, ako dodať telu správnu kombináciu cvičenia a relaxu
#
#     .
#
#     Zlepšíme každú časť, každý systém, vo Vašom tele.
#
#
#     Pracujeme podľa najnovších poznatkov, máme mnoho unikátnych technológií,
#     ktoré Vám zaručia úspech.
#
# Ale hlavne Vás to u nás bude baviť!
# ----------------
# https://multi-sport.sk/aktivity/partner/7-spa/
# Fitness 60min, Wellness 120min s doplatkom 8,00€
# ----------------
# https://multi-sport.sk/aktivity/partner/77-next-level-fitness/
# Vaše nové fitness centrum v centre Bratislavy na Bajkalskej 2i. Čoskoro sa naše fitness centrum rozrastie o ďalších skoro 400m², kde Vám pribudne priestor aj na poriadnu funkčnú zónu plus kopec ďalších biomechanicky výnimočných strojov na ktoré ste u nás zvyknutý!
# ----------------
# https://multi-sport.sk/aktivity/partner/a-fit-centrum/
# Sme tu pre všetkých, ktorí sa chcú zoznámiť s moderným poňatím fitness a     ktorí si myslia, že ich telo si zaslúži patričnú pozornosť a starostlivosť.     Preferujeme komplexnú starostlivosť, preto Vám ponúkame komplexný cvičebný program, ktorý zahŕňa prvky    kardiovaskulárneho aj silového cvičenia zároveň. Posilňuje     svaly, spevňuje telo, zrýchľuje metabolizmus, spaľuje tuky a pomáha stratiť     Vaše kilá navyše :).
#      Môžete prísť kedykoľvek a bez objednania. Vaše cvičenie začína vo chvíli,     kedy prídete. Ako veľké plus máme aj kardio stroje .Čo sa     týka osobných tréningov,profesionálne vyškolený personál Vám bude pomáhať     počas celej doby, počas ktorej budete formovať Vašu postavu.
#      Samozrejmosťou je výživové poradenstvo a celková     starostlivosť. Jedine tak môžete dosiahnuť čo najefektívnejšieho výsledku,     v redukcii hmotnosti aj pri formovaní postavy.
# ----------------
# https://multi-sport.sk/aktivity/partner/activ-club/
# Komplet zariadené klimatizované fitness centrum na precvičenie každej
#     partie tela s výhľadom na okolitú prírodu. K dispozícii sú Vám aj
#     kvalifikovaní fitness tréneri. V ponuke máme rôzne doplnky výživy.
#
#
#     Moderná bedmintonová hala plne osvetlená a vykurovaná s profi povrchom pre
#     skutočný pôžitok z hry. K dispozícii sú šatne pre hráčov a komplet
#     príslušenstvo pre hru. Pitný režim Vám tiež radi zabezpečíme.
#
#
#     Príjemná atmosféra nášho útulného wellness je stvorená na relax a
#     odpočinok. Oddýchnuť ti môžete v bazéne s vírivkami, vo fínskej a parnej
#     saune. Máte k dispozícii odpočiváreň, ochladzovací bazén aj bar.
# ----------------
# https://multi-sport.sk/aktivity/partner/active-arena/
# Unikátna telocvičňa, kde si zacvičia malé deti, teenageri ale aj dospelý.     Naša odpružená podlaha vám dopraje luxus pri cvičení. Mimo organizovaných     tréningov k nám môžeš prísť kedykoľvek si zacvičiť sám alebo so svojim     dieťaťom. Tak isto si môžeš u nás posedieť, dať si kávičku alebo proteín a     zhodnotiť svoje snaženie sa na tréningu.              Naša telocvičňa sa dá prenajať a môžeš si urobiť detskú párty či inú         oslavu          . U nás sa vytvárajú tie pravé zážitky.
# ----------------
# https://multi-sport.sk/aktivity/partner/active-gym/
# Nové fitko v Leviciach, ACTIVE GYM, na Vojenskej ulici 114.
#
#     Na 200 m2 cvičebnej plochy je kardio zóna, silová zóna a samozrejme aj
#     kvalitné profesionálne stroje. Každý si tu nájde svoje v príjemnej až
#     rodinnej atmosfére. Samozrejmosťou je možnosť trénovať pod dohľadom
#     skúseného trénera alebo si nechať poradiť od ochotného personálu.
# ----------------
# https://multi-sport.sk/aktivity/partner/ad-joga-malinovo/
# Kurzy jogy sú príležitosťou spoznať kvalitnú jogu aj nových priateľov, ľudí     s podobnými záujmami a životnými hodnotami. Na lekciách sa popri cvičení     dotýkame aj rôznych oblastí duševného poznania a osobnostného rozvoja.
# ----------------
# https://multi-sport.sk/aktivity/partner/ad-joga-podunajske-biskupice/
# Kurzy jogy sú príležitosťou spoznať kvalitnú jogu aj nových priateľov, ľudí     s podobnými záujmami a životnými hodnotami. Na lekciách sa popri cvičení     dotýkame aj rôznych oblastí duševného poznania a osobnostného rozvoja
# ----------------
# https://multi-sport.sk/aktivity/partner/addiction-club/
# Addiction club je symbolom pre fitness, oddych, zdravý životný štýl. V     skupine to ide ľahšie, a preto dosahujeme výsledky spoločne rýchlejšie.     Koncept Les Mills nás inšpiruje denno-denne a my vám s radosťou ponúkame     cvičenia ako              GRIT™, BODYATTACK™, BODYPUMP™, LES MILLS TONE™, CXWORX™ a BODYBALANCE          ™.
# ----------------
# https://multi-sport.sk/aktivity/partner/agama-golf-klub/
# Agama golf klub ponúka 9 jamkové golfové ihrisko, Driving range, 9 jamkové     footgolfové ihrisko, Golfový bar s vinotékou, Pro shop (golfový obchod)
# ----------------
# https://multi-sport.sk/aktivity/partner/aircraft-sport-house/
# Aircraft Sport House je športové centrum, ktoré sa nachádza blízko
#     nákupného centra Avion.
#
#
# K dispozícii sú služby ako    Fitness centrum so strongman zónou ( 2 000 m2 ),
#
#         Wellness, Boxerňa, tanečné a aerobikové sály a skupinové cvičenia
#
#     . V budove sa takisto nachádza detské centrum Kidshouse a
#     trampolínové centrum Jump Arena.
#
#
#     Zaparkovať môžu návštevníci v podzemnom parkovisku, kde je k dispozícii
#     takmer 200 parkovacích miest
# ----------------
# https://multi-sport.sk/aktivity/partner/all-stars-gym/
# U nás nájdete špičkovo vybavenú posilňovňu s    kardio zónou a funkčnou zónou o rozlohe vyše 400m2. K     dispozícii je proteínový bar, v ktorom je možnosť zakúpiť, či dať si     namiešať, výživové doplnky značky ALL STARS. Taktiež u nás nájdete     kvalifikovaných osobných trénerov s profesionálnym     prístupom pod dohľadom dlhoročného štátneho trénera SAKFST (IFBB) v     kulturistike a fitness Mgr. Ľuboša Matejíčku.
# ----------------
# https://multi-sport.sk/aktivity/partner/ant-fitgym/
# Sme rodinný podnik, ktorý tohoto roku oslavuje 20. výročie svojho vzniku.     Naše fitnescentrum sa nachádza v budove Centrálu na sídlisku II a     rozprestiera sa na ploche 1020m2. Sme tu pre Vás od pondelka do nedele, 363dní v roku. Našim klientom ponúkameštyri špičkovo vybavené cvičebné sály aveľkú priestrannú posilňovňu s     rozmanitou kardio zónou.
#      To všetko dopĺňa fínska (suchá) sauna s ochladzovacím     bazénom. Našou ideou bolo, a vždy bude ponúkať pohybové programy pre všetky     vekové a výkonnostné skupiny, od detí po seniorov, od zdravotne oslabených     jedincov až po vrcholových športovcov. Ak hľadáte silného partnera pre Vás     aktívny život, ANT Kardiofitness patrí jednoznačne medzi lídrov na trhu v     ponuke skupinových cvičení a odbornosťou, s akou pristupujeme ku našim     klientom.
# ----------------
# https://multi-sport.sk/aktivity/partner/aquaboom/
# Návštevníci kúpaliska majú  k dispozícii :
#     – 50 metrový rekreačný bazén s hĺbkou vody 110 cm až  140 cm
#     – detský bazén s hĺbkou vody 40 cm
#     – druhý detský bazén s hĺbkou vody 15 cm
#
#
#     Voda v bazénoch je vyhrievaná (teplota vody 26 –  29 stupňov)
# ----------------
# https://multi-sport.sk/aktivity/partner/aquacity-poprad/
# AquaCity Poprad je svetom zábavy, relaxu a oddychu
# .
#
#
#     Súčasťou Aquaparku je 13 vonkajších a vnútorných bazénov s termálnou vodou
#     s teplotou 28°C – 38°C, tobogany a viac ako 350 vodných atrakcií. Voda v
#     AquaCity pochádza z prírodného podzemného zdroja a privádza sa do areálu.
#     Technologickým procesom sa z teploty 50°C ochladzuje na 36 až 38°C. Bazény
# majú antikorový povrch, aby sa    minimalizovala potreba používania chlóru. Na jej dezinfekciu sa
#     využíva UV žiarenie, čím je šetrná k pokožke i k očiam.
#
#
#
#         Voda v termálnych bazénoch pramení z hĺbky 1300m a obsahuje viac ako 20
#         rôznych minerálov priaznivo pôsobiacich na zdravie človeka.
#
#
#     Pomáha pri problémoch s pohybovým a dýchacím ústrojenstvom, krvnému obehu,
#     nervovej sústave a má aj priaznivé kozmetické účinky.
# ----------------
# https://multi-sport.sk/aktivity/partner/aqualand-plazove-kupalisko/
# Priestranný AQUALAND s rozľahlými vodnými plochami na kúpanie(22.000 m2) a zábavu (6.000 m2), plochami na ležanie a oddych(25.000 m2) umožňuje ulahodiť každému návštevníkovi. Vodný zábavný park (1.000 m2) s vodnými trampolínami, skákadlami, množstvom prekážok a aquazorbingom.
# ----------------
# https://multi-sport.sk/aktivity/partner/aquapark-kovacova/
# Zábava & Relax & Aktívny oddych
#
#
#     …všetko na jednom mieste…
#
#
# Holidaypark Kováčová
#
#
#     Holidaypark nie je len o relaxe v termálnej liečivej vode, ale aj o
#     strávení príjemných chvíľ a zábavy s rodinou alebo s priateľmi.
#     Uvoľnite svoje telo aj myseľ v termálnej liečivej vode v Holidayparku
#     Kováčová. Naša voda je termálna, hypotonická, minerálna,
#     síranovo-hydrouhličitanová, vápenato-horečnatá.
#     Holidaypark Kováčová ponúka skvelú kombináciu služieb pre aktívny oddych.
#     Okrem relaxu v termálnej liečivej vode môžete svojmu telu a mysli dopriať
#     aj cvičenie vo vode, Fit Parku alebo na trampolínach.
# ----------------
# https://multi-sport.sk/aktivity/partner/aquapark-senec/
# Aquapark Senec je  prevádzka ktorá je
#
#         otvorená celoročne
#
#     a zabavia sa v nej všetky  vekové kategórie. Počas letnej sezóny je otvorený
#     celý vonkajší areál, kde sa  nachádzajú farebné tobogany, bazény, gastro
#     prevádzky, detské ihrisko, skákací  hrad.
#
#
#     Pre rodiny s deťmi je pripravený počas celého roka bohatý  animačný program
#     farebná penová párty každý deň, rôzne súťaže, odmeny.
#
#
#     Nachádza sa tu hlavná  reštaurácia s výhľadom na letný areál, a 4 bufety
#     (PIZZA, BURGER,  PALACINKA, GRILL), Pool Bar. Parkovanie, skrinky a  ležadlá
#     (v prípade dostupnosti) sú zdarma.
# ----------------
# https://multi-sport.sk/aktivity/partner/aquapark-trnava/
# Projekt Aquaparku Trnava, pôvodne Relax Aqua & Spa, bol nepochybne
#     veľkou výzvou. V konečnom návrhu však našli svoje uplatnenie drevené
# konštrukcie a prvky, vďaka čomu sa môže    Aquapark Trnava pýšiť titulom drevostavba, za čo v roku
#     2015 získal ocenenie.
#
#
#     V našich bazénoch nájdete slanú vodu. Ako je to možné?
#     Vodu v bazénoch ošetrujeme soľou. Vďaka tomu je voda čistejšia,
#     priezračnejšia a je menej agresívna na pokožku a oči. Vzhľadom na
#     dezinfekčné účinky soli, takto upravená voda zabíja nežiadúce organizmy,
#     ktoré by sa v nej mohli nachádzať.
#
#
#     Pri Vašej najbližšej návšteve Wellnessu sa
#
#         zhlboka nadýchnite a nechajte na seba pôsobiť čisto prírodné vône
#
#     . Preneste sa do Austrálie cez vôňu eukalyptu, Áziu prináša jazmín a
#     rumanček alebo navštívte lesy nášho krásneho Slovenska s vôňou lesného
#     ihličia. Naše arómy tvoria prírodné látky, ktoré vydržia aj vysoké teploty
#     sáun.
# ----------------
# https://multi-sport.sk/aktivity/partner/aquarelax/
# Je to ideálne miesto pre Vaše oddychové, ale aj profesionálne plávanie, organizovanie plaveckých pretekov, sústredení, školských plaveckých kurzov aj pre tie najmenšie deti.
# ----------------
# https://multi-sport.sk/aktivity/partner/arboretum-mlynany/
# Arborétum Mlyňany bolo založené v roku 1892 vášnivým  záhradníkom,
#     dendrológom Dr. Štefanom Ambrózy – Migazzim, ktorý prvé výsadby  realizoval
#     na ploche 40 ha, na morfologicky jedinečne členenom kúsku územia,  v
#     podraste dubovo – hrabového lesa neďaleko Zlatých Moraviec. Vznikla tak
#     prvá vždyzelená dendrologická zbierka v strednej Európe. Súčasne s prvými
#     výsadbami začal budovať  aj novoklasicistický kaštieľ, ktorý je dominantou
#     Arboréta Mlyňany. Kaštieľ a  pôvodný Ambrózyho Semper vireo park sú
#     národnou kultúrnou pamiatkou.
#
#
#     V roku 1953 sa stalo Arborétum Mlyňany súčasťou  Slovenskej akadémie vied,
#     čím sa  vytvorili podmienky pre intenzívny rozvoj vedecko-výskumnej činnosti
#     a rozširovanie zbierok drevín.
#
#
#     Dnes je Arborétum Mlyňany s rozlohou 67 ha najväčším  slovenským arborétom a
#     jeho súčasťou sú okrem pôvodnej zbierky vždyzelených  drevín aj  nové
#     expozície východoázijskej  dendroflóry, časť so severoamerickou
#     dendroflórou, expozícia slovenskej  dendroflóry a rozárium. Prezentácia
#     zbierok drevín, vzdelávacie  a popularizačné aktivity sú ďalšie významné
#     činnosti Arboréta Mlyňany,  ktoré ročne navštívi okolo 40 000 návštevníkov.
#
#
#     Základné  informácie :
#     – zbierka viac ako 1950 taxónov drevín na ploche 67 ha,
#     – výsadba rastlín na báze fytogeografického princípu,
#     – duby letné staré viac ako 200 rokov a vyše 130 ročné Severoamerické  a
#     Ázijské konifery,
#     – rozárium s viac ako 200 kultivarmi ruží.
# ----------------
# https://multi-sport.sk/aktivity/partner/areal-bezeckeho-lyzovania-bachledka-ski-sun/
# Neobmedzený vstup na bežkarske trate.  Spoločnosť MultiSport je partner tohtoročnej zimnej sezóny.
# ----------------
# https://multi-sport.sk/aktivity/partner/areal-bezeckeho-lyzovania-certovica/
# Neobmedzený vstup na bežkárske trate. Spoločnosť MultiSport je partner tohtoročnej zimnej sezóny.
# ----------------
# https://multi-sport.sk/aktivity/partner/areal-bezeckeho-lyzovania-jakaski-jahodna/
# Neobmedzený vstup na bežkarske trate.  Spoločnosť MultiSport je partner tohtoročnej zimnej sezóny.
# ----------------
# https://multi-sport.sk/aktivity/partner/areal-bezeckeho-lyzovania-jakaski-jahodna-areal-anicka/
# Neobmedzený vstup na bežkarske trate.  Spoločnosť MultiSport je partner tohtoročnej zimnej sezóny.
# ----------------
# https://multi-sport.sk/aktivity/partner/areal-bezeckeho-lyzovania-kojsovska-hola/
# Neobmedzený vstup na bežkarske trate.  Spoločnosť MultiSport je partner tohtoročnej zimnej sezóny.
# ----------------
# https://multi-sport.sk/aktivity/partner/areal-bezeckeho-lyzovania-levoca-nordic-centrum/
# Neobmedzený vstup na bežkarske trate.  Spoločnosť MultiSport je partner tohtoročnej zimnej sezóny.
# ----------------
# https://multi-sport.sk/aktivity/partner/areal-bezeckeho-lyzovania-liptovska-kokava/
# Neobmedzený vstup na bežkarske trate.  Spoločnosť MultiSport je partner tohtoročnej zimnej sezóny.
# ----------------
# https://multi-sport.sk/aktivity/partner/areal-bezeckeho-lyzovania-nbc-osrblie/
# Neobmedzený vstup na bežkárske trate.  Spoločnosť MultiSport je partner tohtoročnej zimnej sezóny.
# ----------------
# https://multi-sport.sk/aktivity/partner/areal-bezeckeho-lyzovania-park-snow-donovaly/
# Neobmedzený vstup na bežkarske trate.
#
#
#     Spoločnosť MultiSport je partner tohtoročnej zimnej sezóny.
# ----------------
# https://multi-sport.sk/aktivity/partner/areal-bezeckeho-lyzovania-pezinska-baba/
# Neobmedzený vstup na bežkárske trate.  Spoločnosť MultiSport je partner tohtoročnej zimnej sezóny.
# ----------------
# https://multi-sport.sk/aktivity/partner/areal-bezeckeho-lyzovania-skalka-pri-kremnici/
# Neobmedzený vstup na bežkárske trate.  Spoločnosť MultiSport je partner tohtoročnej zimnej sezóny.  Partner na ďaľšiu úpravu tratí vyberá dobrovoľný príspevok 4€.
# ----------------
# https://multi-sport.sk/aktivity/partner/areal-bezeckeho-lyzovania-tatraheim/
# Neobmedzený vstup na bežkarske trate.  Spoločnosť MultiSport je partner tohtoročnej zimnej sezóny.
# ----------------
# https://multi-sport.sk/aktivity/partner/areal-sportu-a-relaxu-aquarea-cierna-voda/
# Areál športu a relaxu AQUAREA sa nachádza v okrese Galanta medzi obcami     Veľké Úľany – Nové Osady a Čiernou Vodou. Rozprestiera sa pri krásnom     priezračnom jazere o rozlohe 22 ha a je určený pre rodiny s detmi,     športovcov a milovníkov pobytu v prírode.
#      Areál sa delí na hlavnú a prémium zónu. V hlavnej zóne nájdete              športové ihriská – plážový volejbal, petang, požičovňa kajakov, štrkové         pláže a detský lanový park – TARZÁNIA.          V prémium zóne sa nachádza potápačská základňa s     požičovňou výstroja, miesta na prenájom za účelom              stanovania, rybolovu, príp. orgnizovania spoločenských, firemných a         rodinných podujatí.
#      V areáli nájdete 3 gastro prevádzky: bufet & bar ARKÁDIA s rýchlym     občerstvením a nápojmi, bufet HARPÚNA s čerstvými domácimi lángošmi a     sladkými donutmi, kaviareň FRESH & COFFEE s výberovou kávou zn. PURO a     so zmrzlinou/nanukmi zn.ALGIDA. Tešíme sa na Vašu návštevu 🙂
# ----------------
# https://multi-sport.sk/aktivity/partner/arena-gym/
# Sme fitness centrum zaoberajúce sa silovým a kondičným tréningom v Považskej Bystrici.
# ----------------
# https://multi-sport.sk/aktivity/partner/arena-mariana-gaborika/
# Aréna Mariána Gáboríka ponúka dvojpodlažné fitnes centrum s aerobik zónou.     K dispozícii máme kvalitné moderné zariadenia –              bežiaci pás, eliptický trenažér, bicyklový ergometer, stepper a iné.          Nájdete tu aj špeciálne značkové stroje TECHNOGYM vybavené dotykovou     obrazovkou s technológiou iPAD-u. K dispozícii počas cvičenia máte TV,     internet alebo rádio.
#  Je otvorené denne od 7:00 do 22:00 hod.
# ----------------
# https://multi-sport.sk/aktivity/partner/arena-padel/
# Príď si k nám vyskúšať PADEL – šport 21. storočia!
#
#
#     V Bratislavskej Rači (Na Pántoch 8) sme pre Vás otvorili prvú a jedinú
#     padel arénu na Slovensku s tými najkvalitnejšími World Padel Tour kurtami,
#     moderným zázemím či športovým barom.
#
#
# Prečo je práve padel športový fenomén súčasnosti?
#
#
#     • Padel je považovaný za najrýchlejšie rastúci šport sveta
#     • Úspešne kombinuje tie najlepšie prvky tenisu, squashu a raketbalu
#
#
#     • Eliminuje negatívne aspekty spomínaných športov: tvrdý povrch nevhodný na
#     kolená (tenis, squash), vysoká technická náročnosť (tenis), nevyrovnanosť
#     podania (tenis), silový aspekt (squash), kondičná pripravenosť a pod…
#     • Padel hrajú štyria hráči na kurte o velkosti tenisového, no bez out-ov,
#     ktorý je obkolesený sklom
#     • Pravidlá umožňujú odraz loptičky od steny, čo má za následok dlhšie,
#     rôznorodejšie a zaujímavejšie výmeny
#     • Na menšom kurte, uzavretom kurte je jednoduchšia sociálna interakcia a
#     tvorí tak prirodzenú súčasť hry
#     • Používajú sa špeciálne rakety a loptičky sú veľmi podobné tým tenisovým
#     • Počítanie bodov je obdobné ako v tenise
#     • Servis sa v padeli hrá vždy zdola po odskoku loptičky od zeme
#     • Padel je moderný komunitný šport vhodný pre všetky vekové aj výkonnostné
#     kategórie
# ----------------
# https://multi-sport.sk/aktivity/partner/arny-club/
# Projekt moderného, priestranného a všestranne vybaveného fitness centra,     ktorý je cenovo dostupný pre širokú verejnosť. Fitness centrum s celkovou rozlohou 1000m2, vybavené profesionálnymi    fitness a kardio zariadeniami americkej značky LIFE     FITNESS a HAMMER STRENGHT priamo v centre Liptovského Mikuláša s parkovaním     zadarmo.
# ----------------
# https://multi-sport.sk/aktivity/partner/asana-pezinok/
# Ásana vám prináša kvalitné kurzy jogy v Bratislave, Pezinku a Svätom Jure.     Na našich hodinách jogy sa venujeme zdravému pohybu prostredníctvom cvičení jogy, s dôrazom na ich estetickú a umeleckú formu.    Cviky, zamerané na chrbticu, vedú k ozdraveniu chrbáta a     často pomáhajú odstrániť fyzickú bolesť, napríklad pri sedavom zamestananí.
#      Zároveň sa u nás naučíte, ako usporiadať svoju psychiku, čo vám pomôže     dospieť k harmonickému pomeru medzi vnútornou aktivitou a uvoľnenosťou.     Usporiadanie psychiky vás dovedie k uvoľneniu mysle, pričom zostanete bdelý     a aktívny.
#      Okrem kurzov jogy v našej akadémii ponúkame aj kvalitné vzdelávanie     inštruktorov jogy, semináre jogy a jogové pobyty. Zabezpečujeme aj cvičenie jogy vo firmách alebo individuálne hodiny jogy.    Poradíme vám aj v oblasti výživy a meditácie. Viac nájdete     na www.asana.sk
# ----------------
# https://multi-sport.sk/aktivity/partner/astoria-fit-gym/
# Staráme sa a pomáhame všetkým, ktorým záleží na zdravom životnom štýle.
#     Predstavujeme Vám najväčšie fitness centrum či posilňovňu:) v Košiciach –
#     ASTORIA FIT&GYM, ktoré sme vybudovali od „základu“.
#
#
#     Pomáhame širokej verejnosti splniť si ich sen, či už to je dobre vyzerať,
#     mať fyzickú „kondičku“, nabratiu svalovej hmoty, či schudnutiu….
#
#
#     Sme slobodná firma, ktorá má profesionálny a rešpektujúci management.
#     Unikátnym skĺbením nášho know-how a dostupných moderných technológii sa
#     snažíme byť top fitness centrom vo svojom okolí. Cvič aj TY medzi
#     príjemnými ľuďmi v modernom a dobre vybavenom fitness centre o rozlohe
#     1.100m2 v OC ASTÓRIA na Južnej triede 29 v Košiciach. Garantujeme Vám, že
#     svoje miesto si tu nájdu všetky typy cvičencov, tak nároční ako aj
#     sviatoční.
# ----------------
# https://multi-sport.sk/aktivity/partner/atlas-gym/
# Tešiť sa môžete na rozmanitú škálu silového a funkčného vybavenie od
#     klasických činiek až po sandbagy, pneumatiky či dokonca loglift.
#
#     Pevne veríme že si prídete u nás na svoje a prídete sa k nám riadne vyzúriť.
# ----------------
# https://multi-sport.sk/aktivity/partner/baddy-fitness-branisko/
# Fitness centrum sa nachádza na sídlisku Nad jazerom v OC Branisko je pre všetky vekové kategórie a širokú verejnosť. Fitness centrum má rozlohu 700m2 a ponúka najmodernejšie posilňovacie stroje na trhu.
# ----------------
# https://multi-sport.sk/aktivity/partner/baddy-fitness-tahanovce/
# Fitness centrum Baddy Fitness na sídlisku Ťahanovce sme pre Vás otvorili v novembri 2015 na ulici Americká trieda 11 v Košiciach. Nachádza sa na 1.poschodí nad potravinami Fresh a drogériou DM.  Fitnescentrum je vybavené novými profesionálnymi posilňovacími strojmi od slovenského výrobcu značky DAFE a kardio strojmi od popredných svetových výrobcov Life fitness, Star trac. Fitnescentrum je klimatizované o celkovej rozlohe 472 m2. V prípade, že netušíte, ako sa na jednotlivých strojoch cvičí, kontaktujte niektorého z našich osobných trénerov. Ten vám poradí ako správne cvičiť a tiež Vás bude motivovať k dosiahnutiu Vašich cieľov. Tešíme sa na Vašu návštevu.
# ----------------
# https://multi-sport.sk/aktivity/partner/bafit-academy/
# BAFIT Academy je pohybová akadémia skupinových a individuálnych cvičení v     Banskej Bystrici a v Brezne.
#      Tu nájdeš všetko pod jednou strechou.
# ----------------
# https://multi-sport.sk/aktivity/partner/baseline-sport-arena/
# ZÁKLADNÁ LINKA Tenisového centra
#      BASELINE Športová aréna
#      Sme prvou tenisovou halou v Banskej Bystrici, ktorá ponúka kompletné     zázemie pre rekreačných, ale aj profesionálnych hráčov tenisu.
#      V začiatkoch prípravy sme vychádzali z myšlienky do Banskej     Bystrica tenisový komplex, v ktorom môžu začať začínať od základu     čiary, z čoho vznikol aj názov BASELINE.
#      Ponúkame Vám priestor na zlepšenie svojej hry od základov, či už ste     rekreačný alebo profesionálny hráč.
#      Baselina sport aréna sa nachádza na Švermovej ulici na bývalých tenisových     ihriskách hotela Dixon a ponúkne Vám celoročné hranie tenisu na troch     krytých tenisových ihriskách s akrylátovým, ITF certifikovaným povrchom     Rebound HSA Club v letnej sezóne hranie aj na šiestich vonkajších     antukových kurtoch.
#      BASELINE SPORT ARENA myslí aj na budúcnosť slovenského tenisu a preto     spolupracujeme s tenisovou školou BASELINE as tenisovým klubom TC BASELINE     Banská.
# ----------------
# https://multi-sport.sk/aktivity/partner/bb-gym-11/
# Najmodernejšie a najväčšie FITNESS centrum v Banskej Bystrici. Plocha cez 1500m2.
# ----------------
# https://multi-sport.sk/aktivity/partner/bellator-area/
# Sme priestor, kde si zacvičíš nielen fyzicky, ale aj mentálne v príjemnej     atmosfére rodinného a priateľského nastavenia.
#      Priestor máme rozdelený na power zónu, legs zónu a workout zónu, kde si     každý určite nájde to svoje.
#  Stroje máme špeciálne vyrobené    aj pre hendikepovaných a ľudí na invalidnom vozíku, ktorí     si tiež k nám môžu prísť plnohodnotne zacvičť a vypnúť hlavu.
# ----------------
# https://multi-sport.sk/aktivity/partner/bikesharing-rekola-bratislava/
# S  kartou MultiSport máte 2 voľné jazdy denne
#
#
#
#     V v aplikácii Rekola v menu
#     pod Nastavenia a  tarifa zadajte číslo vašej MultiSport karty. To
#     je celé.
#     Vďaka nej môžete čerpať každý deň 2 voľné jazdy, každú do 60 minút. A k tomu
#     môžete stále navštíviť aj 1 vybrané športovisko.
# ----------------
# https://multi-sport.sk/aktivity/partner/black-river-golf-resort-bernolakovo/
# 1 košík na Driving Range – 36 loptičiek v golfovom  areáli Bernolákove
# ----------------
# https://multi-sport.sk/aktivity/partner/body-centrum-jablonski/
# BODY – CENTRUM je stredisko so sídlom vo Zvolene a širokou pôsobnosťou na
#     celom území SR. Poskytujeme klientom komplexné služby v oblasti zdravia.
#
#     Nosným programom je diagnostikovanie pohybového aparátu a následne príprava
#     cieleného pohybového programu. Programy sú zamerané na chrbticu a kĺby,
#     srdcovo-cievny aparát, ako i formovanie postavy.
#
#     Ponúkame rôzne procedúry a terapie v oblasti regenerácie, rekondície a
#     rehabilitácie.
# ----------------
# https://multi-sport.sk/aktivity/partner/body-magic/
# Bodymagic je rodinne založené fitness a wellnes centrum zamerané na    efektívne využívanie technológii v praxi. Vždy sme chceli
#     ukázať ľuďom že technológie a inovácie dobre fungujú v oblasti fitness,
#     wellness a hlavne v oblasti zdravia. Nie sme veľmi zameraní na obrovské
#     premeny a kulturistiku, ale predovšetkým na zdravotné benefity.
#
#         Aby sa ľudia cítili dobre keď k nám prídu, aj keď od nás odídu
#
#     . Aby sa tešili na naše služby…
#
#
#
#         Prečo „BodyMagic“?
#
#
#     Máme „kúzlo“ – technológiu. A chceme dokázať, že naše „kúzlo“ vie premeniť
#     ľudské telo.
#
#
#
#         Prečo by mali zákazníci prísť práve k nám?
#
#
#     Sme inovatívni a zodpovední. Máme ľudský, rodinný prístup, vieme s ľuďmi
#     pracovať a baviť sa. Keď ľudia k nám prídu, cítia sa v pohode. Vznikajú tu
#     výborné medziľudské vzťahy a oni k nám chodia opakovane a radi….“
#
#
#     Je potrebné sa vopred objednať buď telefonicky alebo pomocou rezervačného
#     formulára :
#
#     📲0905 715 258
#
#     📲rezervačný formulár
#
#     📲 www.bodymagic.sk
# ----------------
# https://multi-sport.sk/aktivity/partner/bodyfit/
# PREČO PRAVIDELNE TRÉNOVAŤ A PREČO PRÁVE U NÁS?
#
#
#     Sme tím odborníkov pripravených ukázať ti ako správne na to, aby si si
#     plnil svoje ciele za lepším a zdravším ja. Je na tebe či sa rozhodneš pre
#     tréning individuálny, vo dvojici, XBODY alebo skupinový. Vždy ti radi
#     pomôžeme či už zlepšiť kondíciu, získať väčšiu silu, vyzerať lepšie ale
#     hlavne, cítiť sa zdravšie.
#
#
#     Tak naskoč na túto vlnu za zdravým životným štýlom spolu s nami a príď sa
#     presvedčiť, že je to tá správna cesta a ukáž nám, čo všetko sa v tebe
#     skrýva a kam až dokážeš zájsť!
#
#
#     Sme v tom spolu!
# ----------------
# https://multi-sport.sk/aktivity/partner/bodyline-fitness-centrum/
# Bodyline Fitness Centrum je miesto pre zdravý životný štýl. Športové     aktivity si môžete užívať v priestoroch posilňovne, Cross gym zóny, Box     clubu, Spinningu a Fitness baru. Pre nadšencov opaľovania ponúkame dve     vertikálne Turbo Soláriá. Tešíme sa na vašu návštevu.
# ----------------
# https://multi-sport.sk/aktivity/partner/bodyworld-fitness-wellness-complex/
# Nezáleží na tom, či ste začiatočník alebo pokročilý, či dávate prednosť
#     individuálnemu cvičeniu, alebo vás viac motivuje „makať“ v skupine, alebo
#     chcete vyskúšať niečo nové, prípadne sa venovať osvedčenému tréningu.
#
#
# V BodyWorld Fitness vyhovieme všetkým vašim požiadavkám.
#
#
#     Fitness centrum je typu takzvaného „open gymu”, ktorý je rozdelený na
#     viaceré zóny. Nájdete tu fitness, kardio, funkčnú a silovú zónu.
# ----------------
# https://multi-sport.sk/aktivity/partner/boom-house/
# Sme rodinno – zábavné centrum, ktoré sa nachádza v príjemnom a v tichom     prostredí vo Svite. Z prednej strany s výhľadom na Vysoké Tatry, zo zadnej     strany z výhľadom na les a prírodu. Toto krásne a láskou vytvorené     prostredie uzrelo svetlo sveta pred troma rokmi. Svet je plný stresov,     strachov, ťažkých situácií, konfliktov,chorôb a nebezpečia. Vieme, že si     potrebujeme nájsť chvíľku pre seba. Chvíľku, kedy my sme na prvom mieste,     chvíľku na svoju duševnú a fyzickú očistu. Potrebujeme uvoľniť stres,     vykompenzovať si sedavú prácu fyzickou aktivitou, a naopak manuálnu prácu     relaxom.
#      Vytvorili sme pre Vás priestory na niekoľko možných činností, ktoré Vás     budú napĺňať, dobíjať a robiť šťastnými. Vytvorili sme priestor pre detí,     mladých, rodičov, starých rodičov a vlastne všetkých, ktorí hľadajú teplo     domova, oddych, pohyb a relax pod jednou strechou. Či sú to ľudia, ktorí si     chcú vychutnať kávu so špaldovými palacinkami v kaviarni, rodičia, ktorí     doprajú deťom aktívny pohyb v interiérovom ihrisku a popri tom sa venujú     priateľom, rodine, alebo si len tak sadnú a čítajú knihu, mladší a starší,     ktorí nájdu svoje miesto vo fitness centre, alebo tí,     ktorí vyhľadávajú skupinové cvičenia. Pod jednou strechou     sme pre Vás vybudovali detský svet pre deti, so zameraním     od najmenších až po teenagerov. Súčasťou centra je samostatná party room, v     ktorej je miesto na organizovanie detských osláv a ktorá     zároveň slúži na spoločenské hry a iné detské záujmové aktivity.
# ----------------
# https://multi-sport.sk/aktivity/partner/bouldrofka-lezecka-stena/
# BouldroFka je malá lezecká stena v Trnave, bouldrovka po trnavsky     bouldroFka.
#      Príďte si zaliezť s kamarátmi, spoznať nových ľudí, posedieť v príjemnom,     horolezecky ladenom prostredí.
#      Náš priestor je spojením lezenia a posedenia s výhľadom na historickú     dominantu Trnavy, trnavský cukrovar.
# ----------------
# https://multi-sport.sk/aktivity/partner/bowling-dixon-resort/
# V BRICK Bar&Bowling si okrem bowlingu môžete zahrať aj stolný futbal, či zahádzať šípky. K dispozícii sú 4 bowlingové dráhy, pričom jedna z nich sa dá upraviť na mantinelovú – vhodnú pre deti. Zároveň sa dá v podniku príjemne posedieť pri dobrej hudbe, pochutiť si na čerstvej pizzi, či ďalších jedlách z našej ponuky. Samozrejmosťou je široký výber nápojov.
# ----------------
# https://multi-sport.sk/aktivity/partner/bowling-erika/
# Dnešné bowlingové centrá slúžia širšej palete zákazníkov ako kedykoľvek     predtým: usporadúvajú sa tu ligové a otvorené turnaje, ale sú tu aj hráči,     ktorí hrajú bowling len pre zábavu, pri podnikových akciách, oslavách     narodenín dospelých a detí, párty s priateľmi a pod.
# ----------------
# https://multi-sport.sk/aktivity/partner/bowling-lineas/
# Bowling je šport vhodný pre všetky vekové kategórie. Svojimi jednoduchými     pravidlami ponúka možnosť usporiadať turnaj družstiev, ale aj jednotlivcov.     Je obľúbenou atrakciou pri firemných večierkoch a rodinných pobytoch, kde     sa dokáže zabaviť celá rodina. Priamo v hoteli si ho máte možnosť zahrať v     bowlingovom bare, kde je pre Vás pripravených 6 dráh a príjemný personál.
#      Zapožičiame Vám aj špeciálnu bowlingovú obuv rôznej veľkosti. V bare     nájdete širokú ponuku alkoholických a nealkoholických nápojov a rôznych     dobrôt k čapovanému aj tankovému pivku. Bowling bar je svojou kapacitou 100     miest              vhodný na organizáciu firemných večierkov, firemných športových akcií a         teambuildingov.          V letných mesiacoch je otvorená letná terasa.
# ----------------
# https://multi-sport.sk/aktivity/partner/bowling-pri-trati/
# Bowling pri trati je situovaný v prekrásnom prírodnom prostredí     multifunkčného 4 sport Areálu v centre obytnej zóny mesta     Prešov.
#      U nás nájdete výnimočné spojenie reštaurácie s výbornou     kuchyňou, príjemným posedením a profesionálnym bowlingom     (8 dráh so špičkovou technológiou BRUNSWICK), sedením a obsluhou aj pri     dráhach. Súčasťou prevádzky je letná terasa s detským     ihriskom, sezónna pivná terasa a bezplatné parkovanie     priamo v areále.
#      Srdečne Vás pozývame využiť naše služby spojené so zábavou, chutným jedlom,     kvalitným vínom a širokou ponukou nápojov. Svojich zákazníkov si veľmi     vážime a teší nás, keď sa k nám radi vracajú, takže príďte aj vy a posúďte     sami.
# ----------------
# https://multi-sport.sk/aktivity/partner/bowling-strecno/
# Vynovený Bowling Strečno – miesto  pre Vaše spoločenské udalosti.
#
#
# Náš Bowling sa nachádza v malebnej  dedinke Strečno.
#     Prídite si k nám urobiť celodenný  výlet s priateľmi, rodinou, alebo
#     známymi. Naša dedinka je rozmanitá a ponúka všetko po čom  vaše srdce piští!
#     Od histórie až po výbornú gastronómiu.
#
#
#     Dovoľujeme si Vás upozorniť na
#
#         automatický rezervačný systém
#
#     ,  kde si môžete objednať dráhy priamo z pohodlia vášho domova.
#
#
#     Tešíme sa na Vás!
# ----------------
# https://multi-sport.sk/aktivity/partner/brutalka/
# Brutalka lezecká stena predstavuje komplexné športovisko, ktoré je
#     prístupné pre všetky vekové skupiny a lezcov rôznych zručností, od
#     začiatočníkov  po pokročilých. U nás nájdu svoje miesto nielen tí, ktorí sa
#     len začínajú  zaujímať o lezenie, ale aj skúsení nadšenci, ktorí hľadajú
#     nové výzvy.
#
#
#     Naša stena ponúka širokú škálu možností pre lezcov. Patrí medzi ne
#     bouldrovka, detský kútik, vonkajšia bouldrovka, stena s lanom, spraywall a
#     plne  vybavená posilňovňa. To znamená, že bez ohľadu na vaše preferencie či
#     úroveň  zručností, máme pre vás niečo vhodného.
#
#
#     Bouldrovka je ideálna pre tých, ktorí sa chcú zamerať na lezenie  bez lana a
#     vyžaduje od lezcov vysokú úroveň techniky a silu. Pre deti máme  pripravený
#     špeciálny kútik, kde sa môžu bezpečne a s radosťou učiť základy  lezenia.
#     Vonkajšia bouldrovka pridáva do mixu prírodný prvok a nové výzvy.
#
#
#     Stena s lanom poskytuje možnosť lezenia s istením, čo umožňuje  lepšiu
#     kontrolu nad pohybom a bezpečnosť pri zdolaní vyšších trás. Spraywall je
#     miesto, kde sa môžete voľne vyjadriť a trénovať svoje lezecké umenie na
#     jedinečnej ploche. A pre tých, ktorí chcú posilniť svoje telo a zlepšiť
#     svoju  fyzickú kondíciu, je tu naša moderná posilňovňa.
#
#
#     Celkovo sa snažíme vytvoriť prostredie, kde sa každý môže zapojiť  a
#     rozvíjať svoju vášeň pre lezenie bez ohľadu na vek či úroveň skúseností.
#     Naša  stena je viac než len športovisko – je to miesto, kde sa stretávajú
#     rovnako  zmýšľajúci ľudia a vytvára sa komunita zdieľajúca lásku k lezeniu.
# ----------------
# https://multi-sport.sk/aktivity/partner/bungeefit/
# Gravitácia už nie je limitom.
#     Prevedieme Ťa dynamickými rutinami, ktoré nielenže zlepšia fyzický výkon,
#     ale aj  rozvíjajú koordináciu a vďaka elastickým lanám šetria kĺby. Objav
#     radosť z  pohybu s každým skokom, odrazom a vzletom. Bungee Fitnes je
#     dynamické cvičenie,  ktoré kombinuje prvky tradičných fitness rutín so
#     zábavnou formou cvičenia.  Tento nezvyčajný a inovatívny spôsob cvičenia
#     ukazuje telu nové výzvy,  zapája svaly celého tela a zároveň poskytuje
#     intenzívne kondičné cvičenie.
# ----------------
# https://multi-sport.sk/aktivity/partner/byramos-studio/
# BYRAMOS DANCE AND FITNESS STUDIO Ružinov, Bratislava
#
# V byRamos Studio vám s radosťou každý deň ponúkame široký výber z otvorených tanečných a fitness hodín pre deti aj pre dospelých, pre začiatočníkov, pokročilých aj pre profesionálov, súkromné hodiny na želanie, skupinové hodiny dľa rozvrhu, špeciálne víkendové workshopy, rýchlokurzy pre zaneprázdnených, školenia inštruktorov, detské pohybové letné campy a prípravky, tančiarne v štýle latino párty a ešte k tomu aj DJa pod jednou strechou.
#  Všetci sú v byRamos Studio v Ružinove srdečne vítaní.  Multisport platí na všetky fitness hodiny a všetky otvorene tanečné hodiny (okrem kurzov) podľa aktuálneho rozvrhu.
#
# Zumba fitness s Danielou  Pridajte sa  naše pravidelné Zumba hodiny v Bratislave, ktoré vysielame aj ONLINE. Vítaní sú všetci bez ohľadu na vek, kondíciu, či tanečné skúsenosti. Čaká Vás skvelá a uvoľnená atmosféra, najlepšie je prísť vyskúšať a presvedčiť sa na vlastné oči.  V Bratislave spolu cvičíme už 16 rokov a riadime sa heslom: Zabudnite na cvičenie a dostaňte sa do formy na party!
#  Pozrite si náš Facebook.
# Aktuálny rozvrh cvičení nájdete tu.
# ----------------
# https://multi-sport.sk/aktivity/partner/cafe-restaurant-castello/
# Bowling je zábava! Poďte sa zabaviť a vychutnať si pôžitok z dobrého jedla,     výborného pivka, či špičkových vín z rôznych kútov sveta. V krásnom, do     detailu premyslenom prostredí, s dvoma bowlingovými dráhami a     profesionálnym biliardovým stolom. Kapacita bowlingu: 40 miest.
#  Ideálne miesto pre akcie rôzneho druhu,    oslavy narodenín, firemné večierky, či teambuilding.
#      Zmeňte stereotyp, zavítajte k nám a užite si zábavu zo súperenia a     vyhrávania, úžasného jedla a jedinečných drinkov.
# ----------------
# https://multi-sport.sk/aktivity/partner/carbon-fitness/
# Jedinečné priestory a neobmedzené možnosti zlepšovať svoje zdravie, byť
#     silnejší, rýchlejší, vytrvalejší a všestrannejší.
#
#
#     Správnou kombináciou toho najlepšieho z rôznych odvetví telesnej kultúry,
#     dosiahnete čokoľvek budete chcieť. Prvky aeróbneho tréningu, vzpierania,
#     gymnastiky, jógy, strongman cvičení a mnohých ďalších.
# ----------------
# https://multi-sport.sk/aktivity/partner/cassovia-badminton-spot/
# Pripravili sme pre Vás možnosť zahrať si rekreačný bedminton v príjemnom
#     prostredí špecializovaných hál a stráviť príjemné chvíle v spoločnosti
#     priateľov pri tomto stále populárnejšom športe.
#
#
#     Veríme, že si toto miesto obľúbite a stanete sa pravidelným návštevníkmi.
# ----------------
# https://multi-sport.sk/aktivity/partner/century-gym/
# Príďte a zacvičte si v novootvorenom fitnesscentre v Spišskom Podhradí. K
#     dispozícii máte množstvo strojov na precvičenie všetkých svalových partií,
#     crossfit zónu a kardio zónu. Tešíme sa na Vás.
# ----------------
# https://multi-sport.sk/aktivity/partner/city-dance/
# Tanečné štúdio CITY DANCE, ktoré úspešne pôsobilo od roku 2017 v Dúbravke,
#     sa sťahuje na Dlhé Diely a pozýva Vás do čarovného sveta spoločenských
#     tancov. Poskytujeme príležitosť pre každého vyskúšať si svoje obľúbené
#     tanečné štýly pod vedením profesionálnych tanečníkov v našej novej tanečnej
#     sále na Pribišovej 19A.
#
#
#     Dospelí si tu taktiež nájdu niečo svoje: Spoločenské tance, Zumba, Latino
#     ladies alebo Tanec na slávnostné údalosti.
#
#     V ponuke sú skupinové aj individuálne lekcie. Existuje možnosť prenajať
#     našu novú modernú klimatizovanú sálu.
# ----------------
# https://multi-sport.sk/aktivity/partner/city-gym-zoc-max-presov/
# Značka City Gym vznikla v roku 2009 otvorením prvého fitnescentra v     zábavno-obchodnom centre MAX Prešov na Sídlisku Sekčov slúžiaceho aj pre tu     najnáročnejšiu klientelu. Pohyb na našich bežiacich pásoch Vám určite     spríjemní TV tuner, ktorý umožňuje sledovať tri televízne programy     (Markíza, Joj, Doma) počas Vášho športového výkonu.
#      Náročnejšiu klientelu určite zaujmú naše stacionárne bicykle, ktoré vďaka     hydraulicky nastaviteľným sedačkám, ergonomickým rúčkam a dokonalej     biomechanike pohybu umožnia cvičiť v najvyššom štandarde a pohodlí.     Príjemný pocit z cvičenia umocní odborne zaškolený a veľmi ústretový     personál, ktorý Vám ochotne poradí vybrať si tú správnu pernamentku do     nášho fitness centra.
#      Cvičením u nás objavíte zdravý životný štýl, zahrňajúci pravidelné fyzické     aktivity a budete sa jednoducho cítiť lepšie. Fyzické zdravie nie je iba     budovanie svalstva, ide aj o držanie tela a koordinácie pohybov. Efektívny     cvičebný program by mal podporovať správne držanie tela a ohybnosť     naťahovaním aj zvyšovaním sily svalstva.
# ----------------
# https://multi-sport.sk/aktivity/partner/city-gym-kosice/
# City gym Košice o rozmere 900m2 a kvalitný výberom strojov záujme rekreačného ale aj skúseného cvičenca. Výber najkvalitnejších strojov Hammer strength a MMA klietky sa stalo fitnes centrum obľúbené pre všetkých milovníkov športu.
# Neváhajte a navštívte nás ešte dnes!
# ----------------
# https://multi-sport.sk/aktivity/partner/cityfitness-2-ruzinov/
# Cityfitness 2 je kvalitne vybavené fitness centrum, má bohatý výber kardio
#     strojov od bežiacich pásov až po schodový trenažér.
#
#     Zacvičiť si môžete na najkvalitnejších strojoch Lifefitness a
#     Hammerstrength.
# ----------------
# https://multi-sport.sk/aktivity/partner/cityfitness-senec/
# Cityfitness je
# nové moderné fitness centrum v Senci.
#
#
#     Naším prvoradým cieľom je zdravý, spokojný a usmiaty klient
#
# Čo sa cvičenia týka, na svoje si u nás prídu všetci
#     . Ponúkame totiž dva pohľady na cvičenie s rovnakým cieľom – cítiť sa fajn.
#
#
# Čo ťa čaká v
#
#         Cityfitness Senec?
#
#
#     – kvalitné stroje Hammer Strength,
#
#     – pohodlné parkovanie,
#
#     – najväčšia funkčná zóna v Senci.
# ----------------
# https://multi-sport.sk/aktivity/partner/crazyfit/
# Hľadáte jedinečnú a zábavnú formy  cvičenia?
#
#         Jumping v Bratislave
#
#     , ktorý nájdete v našom CrazyFit  Fitness Centre, je dokonalým riešením pre
#     vás.
#
#
# Jumping:
# Našou hlavnou vášňou  je jumping, energické a zábavné cvičenie na
#     mini trampolínach za sprievodu  rytmickej hudby. Toto dynamické cvičenie je
#     vhodné pre všetky vekové kategórie  a poskytuje skvelý spôsob, ako zlepšiť
#     svoju kondíciu a zároveň sa dobre  zabaviť. Každý jumping tréning vedie náš
#     vyškolený inštruktor, ktorý  zabezpečuje bezpečné a efektívne cvičenie pre
#     maximálne 14 osôb na tréning.
#
#
# Skupinové Tréningy:
# Pre tých, ktorí  hľadajú výzvu a chcú posilniť celé svoje telo,
#     ponúkame kruhové tréningy. Tieto  intenzívne tréningové sedenie sú skvelé
#     pre rozvoj sily, vytrvalosti a celkovej  fyzickej kondície. Každá lekcia má
#     kapacitu 8 osôb, aby sme zabezpečili dostatočnú  pozornosť od našich
#     trénerov a vytvorili motivujúce prostredie pre každého  účastníka.
#
#
# CrazyFit je miesto, kde sa môžete  stretnúť s priateľmi,
#     zlepšiť svoju fyzickú kondíciu a dosiahnuť svoje fitness  ciele v
#     podporujúcom a povzbudzujúcom prostredí.
#
#
#     Naším cieľom je, aby ste sa u nás  cítili ako doma a získali potrebné
#     nástroje a podporu na dosiahnutie vašich  fitness snov.
#
#
# ...
# https://multi-sport.sk/aktivity/partner/wellness-centrum-palarikovo/
# Wellness centrum je areálom prosperujúceho poľnohospodárskeho podniku
#         Poľno SME, s.r.o.
#
#
#
#     Bolo postavené v roku 2014 s ideou slúžiť potrebám pracovníkov
#     poľnohospodárskeho podniku, športovcov, a taktiež všetkým ľudom z
#     Palárikova a širokého okolia. Výstavbou relaxačného centra sa vytvorili
# predpoklady pre    dokonalý relax, uvoľnenie a regeneráciu síl.
#
#
#     Od roku 2014 prešla dlhá doba a k wellness centru pribudla koniareň,
#     bowling, reštaurácia, kongresové centrum a zrekonštruovaný penzión
# ----------------
# https://multi-sport.sk/aktivity/partner/wellness-detva/
# Doprajte si čas  v novootvorenom wellness centre v Detve. Vychutnajte si
#     tradičné aj  moderné sauny, vírivú vaňu, profesionálnu masáž alebo posedenie
#     pri osviežujúcom  nápoji, ktoré vám pomôžu uniknúť od každodenného stresu a
#     starostí.
#
#
#     Naším cieľom je, aby ste sa u  nás vždy cítili príjemne a uvoľnene. Veríme,
#     že v našom wellness centre nájdete  všetko potrebné pre obnovenie fyzickej
#     aj psychickej rovnováhy. Sme  presvedčení, že prvotriedny relaxačný zážitok
#     vo Wellness Detva vám pomôže zlepšiť  zdravotný stav a zvýšiť výkonnosť.
# ----------------
# https://multi-sport.sk/aktivity/partner/wellness-hotel-patince/
# Tú pravú pohodu spojenú s regeneráciou nájdete v štyroch vnútorných bazénoch v Thermal Parku. Naplnené sú vodou z vlastného termálneho prameňa Hévíz s teplotou 27°C, ktorý vyviera z hĺbky 200 m. Termálna voda sa v Patinciach vyznačuje vysokým obsahom hydrouhličitanov, vápnika, horčíka i síranov a vďaka tomu veľmi priaznivo pôsobí na pohybové ústrojenstvo a proti jeho chorobám.
#
# Nie je nič lepšie pre telo a myseľ ako návšteva Wellness centra. V piatich saunách naberiete nielen energiu do ďalších dní, ale aj výborne posilníte svoju imunitu.
# Doprajte si vnútornú aj fyzickú rovnováhu, výnimočnú wellness starostlivosť a silu prírodných bylín a vonných esencií.
# ----------------
# https://multi-sport.sk/aktivity/partner/wellness-inn/
# INN WELLNESS je nové moderné wellness centrum, ktoré Vás očarí luxusom,
#     prírodnými materiálmi a maximálne pohodovou atmosférou priamo na Zimnom
#     Štadióne v Banskej Bystrici.
#
#
#     Termin si rezevujte v našom rezervačnom systéme
#
#
#         https://services.bookio.com/inn-wellness/widget?lang=sk
# ----------------
# https://multi-sport.sk/aktivity/partner/wellness-masvital-podolinec/
# V našom Wellness je Vám k dispozícii plavecký bazén s  protiprúdom s
#     príjemnou teplotou vody 29 °C. Plávanie v takomto bazéne priaznivo  pôsobí
#     na pohybové ústrojenstvo a rozprúdi lymfatický systém v tele. Oddychovať
#     môžte aj vo vírivej vani-jacuzzy. Súčasťou wellnessu je aj saunový svet,
#     ktorý  má blahodárne účinky na ľudský organizmus.a pomáha detoxikácii tela.
#     kombináciou rôznych druhov sáun (fínska, parná, infra-soľná) môžte podporiť
#     Váš  imunitný systém a pomôcť celkovej regenerácii.
# ----------------
# https://multi-sport.sk/aktivity/partner/wellness-penzion-ferrata/
# Wellness Penzión Ferrata – miesto, kde si skutočne  oddýchnete.
#
#
#
# FERRATA
# Ferrata HZS na Martinské hole začína u nás. Je najstaršou na
#     Slovensku  a vznikla už v roku 2013, odvtedy prešla mnohými úpravami.
#     Vydajte sa na  dobrodružstvo priamo z nášho penziónu. Nezabudnite na
# kvalitnú ferratovú výbavu,  ktorú si s Vašou kartou
#     MultiSport môžete zapožičať priamo na recepcii  penziónu Ferrata.
#
#
# WELLNESS
# Vy relaxujte, my sa o vás postaráme. Pripravili sme pre vás miesto,
#     kde  môžete uniknúť pred každodenným stresom uponáhľaného okolitého sveta.
#     Zabudnite  na zhon všedných dní a nechajte sa rozmaznávať. Zrelaxujte
#     svoje telo i  ducha v saunovom svete, či priestrannej vírivej vani
#     a nakoniec sa schlaďte  v studenom bazéne.
# ----------------
# https://multi-sport.sk/aktivity/partner/wellness-zoborska/
# .
#
#     Wellness Zoborská je vytvorené v unikátnych 150 ročných klenbových
#     zoborských pivniciach 6,5 metra pod povrchom.
#
#
#     Tento zaujímavý priestor, typický tehlovými klenbami, sme premenili na
#     miesto relaxu a pohody, kde si môžete po náročnom dni oddýchnuť v štyroch
#     druhoch sáun, vírivke, netradičnej oddychovni s premietaním relaxačných
#     filmov, Kneippovom kúpeli alebo na vyhrievaných polosedoch. Netradičný
#     priestor, kľukatiaci sa v členitých chodbách, Vám ponúka
#
#         dokonalý wellness pobyt a saunové vyžitie pre najnáročnejších
#
#     . Našou prioritou je vaše pohodlie, čistota a maximálne naplnenie vašich
#     predstáv o dokonalom oddychu.
#
#
#     Vitajte vo Wellness Zoborská!
# ----------------
# https://multi-sport.sk/aktivity/partner/wolf-gym-zlate-moravce/
# Novootvorené fitness centrum v Zlatých Moravciach s novými  kvalitnými
#     strojmi na cvičenie v skvelej lokalite a dobrou dostupnosťou . Klienti  si
#     môžu prísť zacvičiť do príjemnej priateľskej atmosféry kde môžu využiť
#     služby certifikovaných trénerov
# ----------------
# https://multi-sport.sk/aktivity/partner/world-jumping-cierna-voda/
# World Jumping Čierna voda
#
#   World Jumping centrum Čierna voda      predstavuje zábavný program World Jumping, ktorého korene pochádzajú práve     zo Slovenska. Jeho podstatou sú jednoduché poskoky na špeciálne vyvinutú     trampolíny, ktoré sa nachádzajú od ostatných trampolín hlavne pôvodom a     kvalita.
#      „Tvorcovia využili detskú hravosť, ktorá v každom z nás drieme a spojili ju     s dospeláckov cieľavedomosťou. Vedeli, že kĺby sú citlivé na skoky na zemi,     preto sa postavili na trampolínu. Zistili však, že keď do toho začne hrať     dobre pripravená hudba, výsledok na seba nenechá dlho čakať. Boli udýchaní,     unavení no tak širokým úsmevom si povedal, že toto musí skúsiť každý. U     nás sú aj áčikovia vítaní, pretože každý inštruktor vie dobre vysvetliť     techniku a tak aj nováčikovi s chuťou si zatrénovať.“ Takto     zložiť párty na trampolíne jednej z najväčších sietí fitness centier     NEONKA.
# ----------------
# https://multi-sport.sk/aktivity/partner/world-jumping-nitra/
# World jumping Nitra
#  World jumping Nitra     – najväčšie jumping centrum v Nitre.
#      Nové priestory, klíma, vzduchotechnika v centre mesta. Skupinové cvičenie     na patentovaných trampolínach, určené pre všetky vekové kategórie.
#      Jumping je ideálny šport na formovanie postavy, detoxikuje organizmus,     zlepšuje kondičku, znižuje hmotnosť.
# ----------------
# https://multi-sport.sk/aktivity/partner/x-gym/
# X Gym
#
#      Nové, moderné fitness centrum, vybaveným kvalitným zariadením.
#   Vybavenie:
#      – Posilňovacie stroje: Dafe
#      – Počet stanovísk : 55
#      – Rozpätie jednoručiek : 0,5 kg – 50 kg
#      – Kardio cvičenie : 2 x Elektromagnetický bicykel, 3 x eliptical, 3 x bežiaci     pas, 2 x veslovací trenažér, 10x spinner…
#      – Fitlopty, BOSU, karimatky, schodíky … a dostatok železa pre všetkých 🙂
#      Ponúkame široké spektrum doplnkov výživy, miešané proteíny, kávu, čaje,     džúsy…
# ----------------
# https://multi-sport.sk/aktivity/partner/yada-sportove-centrum/
# Športové centrum Yada
#
#   Yada      – športovo-relaxačné centrum vzniklo s cieľom pomáhať Vám, bežným ľuďom.
#      Nie je cieľom z vás urobiť kulturistov s veľkými svalmi, ale pomôcť Vám v     boji so zdravotnými problémami, ako sú:
#      -bolesti chrbta
#      -nadváha
#      Ukázať Vám ako sa zbaviť nadbytočných kíl a nepotrebného tuku Pravidelne     cvičením a zdravou výživou.
#      Našim cieľom je dosiahnutie pekne vyformovanej postavy, zlepšenie     zdravotného stavu a zdravého životného štýlu. Ponukou našich programov chceme     osloviť všetky vekové skupiny. Verím, že nás budete cítiť príjemne a     pohyb sa stane každodennou súčasťou vášho života.
#      Tak nájdete a nás.
# ----------------
# https://multi-sport.sk/aktivity/partner/yogabreak-studio-raca/
# Sme certifikované učiteľky jogy s niekoľkoročnými osobnými skúsenosťami
#     z prostredia korporácií. Vysoké pracovné tempo a sedavé zamestnanie nás
#     inšpirovali k vytvoreniu projektu YOGABREAK, ktorým chceme pomáhať
#     vyťaženým ľuďom, podporovať ich zdravie a vniesť na pracovisko príjemnú
#     energiu.
#     Ponúkame viacero typov lekcií jogy, z ktorých si môžete vybrať presne to,
#     čo sa Vám hodí a čo Vám vyhovuje. Od desaťminútových cvičení pri pracovnom
#     stole až po hodinu plnej jogovej praxe. Hodiny sú zostavené tak, aby sme
#     podporili našich klientov v náročných a stresujúcich obdobiach.
#     Cieľom je budovanie správneho postoja, upokojenie mysle a prevencia
#     vyhorenia.
# ----------------
# https://multi-sport.sk/aktivity/partner/yonex-arena/
# Yonex Aréna patrí medzi najväčšie bedmintonové centrá na Slovensku.
#     Poskytuje hru na 12-tich kurtoch. Na recepcii je možné zakúpiť si menšie
#     občerstvenie a zapožičať si rakety a košíky na hru.
# ----------------
# https://multi-sport.sk/aktivity/partner/you-can-pole-dance/
# Útulné tanečné štúdio na Ovsištskom námestí v Petržalke vás  pozýva na
#     tréningy pole dance pre úplných začiatočníkov.
#     Naše tréningy sú otvorené pre všetky ženy, ktoré chcú skúsiť pole dance a
#     posilniť telo aj dušu zdravým a zábavným spôsobom. Tréningy vedie profi a
#     skúsená inštruktorka, ste obklopené skvelým kolektívom s rovnakým záujmom a
#     dobrá nálada prichádza sama už po pár minútach.
# ----------------
# https://multi-sport.sk/aktivity/partner/zabavne-centrum-brezovec/
# Cieľom nášho centra je poskytovať špičkový tréning svetovej úrovne.
#  Preto sme sa rozhodli spolupracovať s najuznávanejšími fitness značkami
#   na svete – od kardio zariadení, cez silové stroje až po doplnky výživy.
#  Ako člen elitnej skupiny globálnej siete Official Hammer Strength Center
#  sme sa zaviazali pre našich cvičencov poskytovať top kvalitu bez kompromisov.
#  Sme tu pre všetkých, čo chcú zo svojho tréningu vyťažiť maximum – od
#  profesionálnych športovcov po bežných zanietencov fitness.
# ----------------
# https://multi-sport.sk/aktivity/partner/zakladna-skola-konstantinova/
# Základná škola Konštantínova
#
#   Krytá plaváreň Stropkov
#      -plavecký bazén 24×12,5x13m
#      -detský bazén 8x4x0,3m
#   Otváracie hodiny:
#      Utorok-Piatok – 16:30 – 21:00 hod
#      Sobota-Nedeľa – 15:00-21:00 hod
# ----------------
# https://multi-sport.sk/aktivity/partner/zakladna-skola-majove-namestie-1/
# Žiaci ZŠ Májové námestie využívajú bazén pri vyučovaní predmetu plávanie,
#     telesná a športová výchova, ale aj na záujmovú činnosť v rámci Centra
#     voľného času, ktoré je zriadené ako súčasť našej školy.
#
#
#     Naším cieľom je zvyšovanie plaveckej gramotnosti žiakov v klasických
#     plaveckých disciplínach, podpora zdravého spôsobu života a v neposlednom
#     rade aj zmysluplné využitie voľného času detí.
#
#
#     Základné školy mesta Prešov a priľahlých obcí využívajú bazén na plavecký
#     výcvik.
# ----------------
# https://multi-sport.sk/aktivity/partner/zao-mma-gym/
# Telocvična v lokalite Prešov-Sekčov zameraná na MMA, bojové športy, kondičné a funkčné tréningy. Hlavným trénerom je Mgr. Jozef Wittner jednotka vo welterovej váhe, profesionálny MMA zápasník svetovej úrovne so skúsenostami z USA, absolvent Fakulty športu na UNIPO. Skupinové a súkromné tréningy pod vedením certifikovaných trénerov pre všetky výkonnostné a vekové kategórie. MMA tréningy, kondičné tréningy, funkčné tréningy, tréningy pre deti. Súkromné tréningy pre klientov kde má klient pohodu a miestnosť s trénerom len pre seba bez ostatných návštevníkov a iných rušivých vplyvov. Možnosť plnej koncentrácie sa na tréning a na svoje ciele. Redukcia hmotnosti, formovanie postavy, naberanie svalovej hmoty, sebaobrana, box, MMA, zdravotné cvičenia, vypracovanie jedálníčkov a tréningových plánov na mieru.
# ----------------
# https://multi-sport.sk/aktivity/partner/zimny-stadion-banska-bystrica/
# Zimný štadión v Banskej Bystrici patrí k jedným z
#     najstarších zimných štadiónov na Slovensku. Otvorený bol v noci z 24.
#     decembra  na 25. decembra 1956.
#
#
#     Po ukončení generálnej rekonštrukcie (v rokoch 2020-2022) sa  stal Zimný
#     štadión v Banskej Bystrici dôstojným miestom pre organizovanie  hokejových
#     zápasov všetkých kategórií, a bezpochybne spĺňa všetky podmienky na
#     organizovanie zápasov najvyššej súťaže a taktiež medzinárodných
#     krasokorčuliarskych pretekov. Zároveň je naďalej tréningovým priestorom
#     športových klubov, ako aj miestom aktívneho oddychu (hokej, korčuľovanie)
#     pre  širokú verejnosť. Priestor štadióna môže byť využívaný aj na
#     organizovanie  masových hudobných, kultúrnych a spoločenských podujatí
#     vzhľadom k veľkorysej  kapacite priestoru na sedenie i státie.
#
#     Aktuálny rozpis ľadu –
#
#         Hala A-B
# ----------------
# https://multi-sport.sk/aktivity/partner/zimny-stadion-dolny-kubin/
# Zimný štadión sa nachádza na sídlisku Bysterec. Rozmery ľadovej  plochy sú
#     59m x 29m.
#
#
#     Do  prevádzky bol uvedený v roku 1993, v roku 1996 bol zastrešený. Počet
#     miest na  sedenie je 300, počet miest na státie 200. Objekt disponuje 6
#     hosťovskými  šatňami a 7 šatňami pre Mestský hokejový klub, taktiež
#     dostatočným počtom  sociálnych zariadení.
# ----------------
# https://multi-sport.sk/aktivity/partner/zimny-stadion-komarno/
# Azda najatraktívnejším miestom zimného obdobia je    klzisko na Alžbetínskom ostrove. Svoje brány každoročne
#     otvára približne od decembra do februára a teší sa na
#     návštevníkov z mesta a okolitých obcí. Toto športové stredisko tvorí
#     bezpečná a rozsiahla ľadová plocha, vonkajšia a vnútorná prezliekareň a
#     obľúbený bufet, ktorý ponúka teplé nápoje a pekárenské výrobky.
# ----------------
# https://multi-sport.sk/aktivity/partner/zimny-stadion-prievidza/
# Zimný štadión Prievidza
#
#           Zimný štadión vytvára podmienky pre rozvoj telesnej kultúry v         prievidzskom regióne          , svoje aktivity sústredí hlavne na mládežnícky šport. Zimný štadión láka     nielen domácich návštevníkov a športových oddielov, ale aj zahraničných klubov.
#   Rozmery      ľadovej plochy sú 60 mx 30 m.
#   Kapacita      hľadiska je 2 788 miest na sedenie.
#      Štadión je tak vhodným dejiskom športových podujatí, exhibícií, či     kultúrnych akcií. Ľadová plocha je využívaná približne 7 – 8 mesiacov v     roku, čo predstavuje okolo 3 180 až 3 645 hodín ročne.
# ----------------
# https://multi-sport.sk/aktivity/partner/zimny-stadion-vojtecha-zavodskeho-zilina/
# Zimný štadión mesta Žilina sa nachádza v športovom areáli v centre
#         Žiliny a je využívaný najmä na tréningy a zápasy Mestského hokejového
#         klubu Žilina a na tréningy krasokorčuľovania. V zimnom období je
#         taktiež využívaný na verejné korčuľovanie pre verejnosť.
#
#
#
#         Areál zimného štadióna tvoria dve ľadové plochy – hlavná hala a
#         tréningová hala.
# ----------------
# https://multi-sport.sk/aktivity/partner/zoc-koral/
# ZOC KORAL
#
#   Najväčšie Bowlingové centrum v Prešove      s ôsmimi profesionálnymi dráhami v príjemnom prostredí Vám zábavu a     príjemne strávený čas s rodinou alebo priateľmi.
#      Vytvorilo ideálne podmienky pre skúsených aj menej skúsených hráčov. Veľké     priestory bowlingu poskytujú miesto pre firemné večierky, narodeninové     oslavy a zábavu.
# ----------------
# https://multi-sport.sk/aktivity/partner/zona-workout-studio/
# ZONA workout studio, miesto, kde sa meníme spolu.
# S potešením oznamujeme, že sme práve otvorili naše dvere pre teba v Žiline!  Radi ťa privítame do nášho nového, moderného a stimulujúceho prostredia, kde sa tvoje ciele stanú našimi cieľmi. Spoločne vytvoríme komunitu, ktorá sa inšpiruje, podporuje a rastie spolu.
# ----------------
# https://multi-sport.sk/aktivity/partner/zoo-bratislava/
# Sme prírodná zoona úpätí Malých Karpát s rozlohou 96 ha, v  ktorej sa
#     stretáva listnatý les, lúka, chladné údolie a prírodné jazierka.ň
#
#
#     Našou misiou je spájať svet zvierat, ľudí a prírody cez  poznanie a
#     pozitívne zážitky. Prostredníctvom vysokej úrovne starostlivosti o
#     zvieratá, programov záchrany ohrozených druhov a kvalitného vzdelávania
#     plníme  významnú úlohu v aktívnej ochrane prírody.
# ----------------
